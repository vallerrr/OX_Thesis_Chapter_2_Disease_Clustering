# %%
import time
import subprocess
while True:
    bash_command = """
    for file in data/participant/*; do
        dx upload "$file" --path /"$file"
        rm "$file"
    dx upload recorder/recorder_participant.csv --path recorder_participant.csv
    done
    """
    subprocess.run(bash_command, shell=True)
    time.sleep(120)

# %%
# %%bash
# for file in data/participant/*; do
#     echo "$file"
#     dx upload "$file" --path /"$file"
#     rm "$file"
# done
# Out:
# data/participant/83.csv
# ID                          file-GffV6XQJQ3fVxF3fPG9vjfQG
# Class                       file
# Project                     project-GfFjP3QJQ3ffKF3VqqxzGQG7
# Folder                      /data/participant
# Name                        83.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Sun Jan 21 12:51:22 2024
# Created by                  vallerrr
#  via the job                job-GffQF58JQ3fjj4yXy02K1b2Z
# Last modified               Sun Jan 21 12:51:24 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# data/participant/84.csv
# ID                          file-GffV6Y8JQ3fq10F82qp119YP
# Class                       file
# Project                     project-GfFjP3QJQ3ffKF3VqqxzGQG7
# Folder                      /data/participant
# Name                        84.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Sun Jan 21 12:51:25 2024
# Created by                  vallerrr
#  via the job                job-GffQF58JQ3fjj4yXy02K1b2Z
# Last modified               Sun Jan 21 12:51:27 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# data/participant/85.csv
# ID                          file-GffV6YjJQ3fjpQ84vj60jB0q
# Class                       file
# Project                     project-GfFjP3QJQ3ffKF3VqqxzGQG7
# Folder                      /data/participant
# Name                        85.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Sun Jan 21 12:51:27 2024
# Created by                  vallerrr
#  via the job                job-GffQF58JQ3fjj4yXy02K1b2Z
# Last modified               Sun Jan 21 12:51:29 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# data/participant/86.csv
# ID                          file-GffV6ZQJQ3fq10F82qp119Z6
# Class                       file
# Project                     project-GfFjP3QJQ3ffKF3VqqxzGQG7
# Folder                      /data/participant
# Name                        86.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Sun Jan 21 12:51:30 2024
# Created by                  vallerrr
#  via the job                job-GffQF58JQ3fjj4yXy02K1b2Z
# Last modified               Sun Jan 21 12:51:32 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# data/participant/87.csv
# ID                          file-GffV6b8JQ3fvy51785bfYF7K
# Class                       file
# Project                     project-GfFjP3QJQ3ffKF3VqqxzGQG7
# Folder                      /data/participant
# Name                        87.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Sun Jan 21 12:51:33 2024
# Created by                  vallerrr
#  via the job                job-GffQF58JQ3fjj4yXy02K1b2Z
# Last modified               Sun Jan 21 12:51:35 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# data/participant/88.csv
# ID                          file-GffV6f0JQ3fVxF3fPG9vjfQZ
# Class                       file
# Project                     project-GfFjP3QJQ3ffKF3VqqxzGQG7
# Folder                      /data/participant
# Name                        88.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Sun Jan 21 12:51:36 2024
# Created by                  vallerrr
#  via the job                job-GffQF58JQ3fjj4yXy02K1b2Z
# Last modified               Sun Jan 21 12:51:38 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# data/participant/89.csv
# ID                          file-GffV6fjJQ3fjBFQ4KG5q0PkG
# Class                       file
# Project                     project-GfFjP3QJQ3ffKF3VqqxzGQG7
# Folder                      /data/participant
# Name                        89.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Sun Jan 21 12:51:39 2024
# Created by                  vallerrr
#  via the job                job-GffQF58JQ3fjj4yXy02K1b2Z
# Last modified               Sun Jan 21 12:51:40 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# data/participant/90.csv
# ID                          file-GffV6g8JQ3fjPGzQv6KbXXj1
# Class                       file
# Project                     project-GfFjP3QJQ3ffKF3VqqxzGQG7
# Folder                      /data/participant
# Name                        90.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Sun Jan 21 12:51:41 2024
# Created by                  vallerrr
#  via the job                job-GffQF58JQ3fjj4yXy02K1b2Z
# Last modified               Sun Jan 21 12:51:43 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
# data/participant/91.csv
# ID                          file-GffV6j0JQ3fYv849FvzpbFqX
# Class                       file
# Project                     project-GfFjP3QJQ3ffKF3VqqxzGQG7
# Folder                      /data/participant
# Name                        91.csv
# State                       closing
# Visibility                  visible
# Types                       -
# Properties                  -
# Tags                        -
# Outgoing links              -
# Created                     Sun Jan 21 12:51:44 2024
# Created by                  vallerrr
#  via the job                job-GffQF58JQ3fjj4yXy02K1b2Z
# Last modified               Sun Jan 21 12:51:46 2024
# Media type
# archivalState               "live"
# cloudAccount                "cloudaccount-dnanexus"
